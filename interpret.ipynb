# %%
from visual import load
import warnings
warnings.filterwarnings('ignore')
inputPath = './results/MYC'

results, rna = load(inputPath)
# Out:
# There are 1 of interactions has been loaded...

# %%
results
# Out:
#    index         drug       rna  probs1  probs2  probs3  probs4  probs5  \
# 0      0  MYC_RIBOTAC  MYC_IRES   0.853   0.515    0.81   0.893   0.415
#
#    median
# 0    0.81

# %%
rna.loc[0,'median']
